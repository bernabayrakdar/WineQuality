# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing, model_selection
import keras

# %%
from sklearn.preprocessing import  StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.losses import binary_crossentropy
from keras.metrics import Accuracy
from sklearn.metrics import accuracy_score
from keras.layers import  Dropout, Activation, BatchNormalization
from keras.callbacks import EarlyStopping

# %%
data = pd.read_csv("winequality-red.csv")

# %%
y = data['quality']
data.drop(['quality'], inplace=True, axis=1)
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
bins = (2,6,8)
gnames = ['bad', 'nice']
y = pd.cut(y, bins = bins, labels = gnames)

enc = LabelEncoder()
yenc = enc.fit_transform(y)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(data, yenc,  test_size=0.2)
scale = StandardScaler()

scaledtrain = scale.fit_transform(xtrain)
scaledtest = scale.transform(xtest)

# %%
model = Sequential([    
        Dense(128, activation='relu', input_shape=(11,)),        
        Dense(64, activation='relu'),
        Dropout(0.25),
        Dense(64, activation='relu'),
        Dropout(0.25),
        Dense(1, activation='sigmoid')
])
adam = Adam(lr=0.0003)
callback = keras.callbacks.EarlyStopping(monitor='val_loss', 
    patience=5,verbose=1)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(scaledtrain, ytrain,batch_size = 16, epochs=100, callbacks=[callback], validation_data=(scaledtest,ytest))
# Out:
# Epoch 1/100
# 80/80 [==============================] - 2s 13ms/step - loss: 0.5597 - accuracy: 0.8324 - val_loss: 0.3990 - val_accuracy: 0.8469
# Epoch 2/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.8760 - val_loss: 0.3288 - val_accuracy: 0.8469
# Epoch 3/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.3271 - accuracy: 0.8505 - val_loss: 0.2990 - val_accuracy: 0.8469
# Epoch 4/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2667 - accuracy: 0.8865 - val_loss: 0.2842 - val_accuracy: 0.8781
# Epoch 5/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2825 - accuracy: 0.8788 - val_loss: 0.2768 - val_accuracy: 0.8781
# Epoch 6/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.8836 - val_loss: 0.2719 - val_accuracy: 0.8781
# Epoch 7/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2752 - accuracy: 0.8852 - val_loss: 0.2692 - val_accuracy: 0.8781
# Epoch 8/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2574 - accuracy: 0.8878 - val_loss: 0.2669 - val_accuracy: 0.8781
# Epoch 9/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.8869 - val_loss: 0.2631 - val_accuracy: 0.8875
# Epoch 10/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2982 - accuracy: 0.8755 - val_loss: 0.2608 - val_accuracy: 0.8813
# Epoch 11/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2419 - accuracy: 0.8948 - val_loss: 0.2587 - val_accuracy: 0.8906
# Epoch 12/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2439 - accuracy: 0.8941 - val_loss: 0.2572 - val_accuracy: 0.8906
# Epoch 13/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2511 - accuracy: 0.8843 - val_loss: 0.2561 - val_accuracy: 0.8906
# Epoch 14/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2429 - accuracy: 0.8897 - val_loss: 0.2540 - val_accuracy: 0.8875
# Epoch 15/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2382 - accuracy: 0.8908 - val_loss: 0.2540 - val_accuracy: 0.8844
# Epoch 16/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2476 - accuracy: 0.8970 - val_loss: 0.2518 - val_accuracy: 0.8875
# Epoch 17/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2331 - accuracy: 0.9009 - val_loss: 0.2518 - val_accuracy: 0.8906
# Epoch 18/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2386 - accuracy: 0.8873 - val_loss: 0.2540 - val_accuracy: 0.8875
# Epoch 19/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.9101 - val_loss: 0.2495 - val_accuracy: 0.8875
# Epoch 20/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9022 - val_loss: 0.2487 - val_accuracy: 0.8906
# Epoch 21/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.8877 - val_loss: 0.2504 - val_accuracy: 0.8875
# Epoch 22/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2208 - accuracy: 0.9086 - val_loss: 0.2463 - val_accuracy: 0.8844
# Epoch 23/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2319 - accuracy: 0.9079 - val_loss: 0.2480 - val_accuracy: 0.8906
# Epoch 24/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2137 - accuracy: 0.9116 - val_loss: 0.2433 - val_accuracy: 0.8875
# Epoch 25/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.9061 - val_loss: 0.2420 - val_accuracy: 0.8875
# Epoch 26/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2064 - accuracy: 0.9070 - val_loss: 0.2452 - val_accuracy: 0.8906
# Epoch 27/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2174 - accuracy: 0.9034 - val_loss: 0.2397 - val_accuracy: 0.8969
# Epoch 28/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2141 - accuracy: 0.9079 - val_loss: 0.2454 - val_accuracy: 0.8781
# Epoch 29/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2056 - accuracy: 0.9205 - val_loss: 0.2390 - val_accuracy: 0.9062
# Epoch 30/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1925 - accuracy: 0.9257 - val_loss: 0.2403 - val_accuracy: 0.8969
# Epoch 31/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1829 - accuracy: 0.9346 - val_loss: 0.2445 - val_accuracy: 0.8875
# Epoch 32/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2051 - accuracy: 0.9169 - val_loss: 0.2447 - val_accuracy: 0.8813
# Epoch 33/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2031 - accuracy: 0.9162 - val_loss: 0.2372 - val_accuracy: 0.8969
# Epoch 34/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1754 - accuracy: 0.9409 - val_loss: 0.2358 - val_accuracy: 0.8969
# Epoch 35/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1976 - accuracy: 0.9147 - val_loss: 0.2382 - val_accuracy: 0.9031
# Epoch 36/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1690 - accuracy: 0.9358 - val_loss: 0.2366 - val_accuracy: 0.9031
# Epoch 37/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1948 - accuracy: 0.9237 - val_loss: 0.2384 - val_accuracy: 0.8938
# Epoch 38/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1762 - accuracy: 0.9359 - val_loss: 0.2357 - val_accuracy: 0.9000
# Epoch 39/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1892 - accuracy: 0.9181 - val_loss: 0.2392 - val_accuracy: 0.8875
# Epoch 40/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1880 - accuracy: 0.9313 - val_loss: 0.2369 - val_accuracy: 0.8906
# Epoch 41/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2074 - accuracy: 0.9219 - val_loss: 0.2362 - val_accuracy: 0.8969
# Epoch 42/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1687 - accuracy: 0.9452 - val_loss: 0.2311 - val_accuracy: 0.9062
# Epoch 43/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1610 - accuracy: 0.9351 - val_loss: 0.2280 - val_accuracy: 0.9094
# Epoch 44/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1578 - accuracy: 0.9413 - val_loss: 0.2368 - val_accuracy: 0.8906
# Epoch 45/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9392 - val_loss: 0.2351 - val_accuracy: 0.9031
# Epoch 46/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1636 - accuracy: 0.9296 - val_loss: 0.2300 - val_accuracy: 0.9156
# Epoch 47/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9430 - val_loss: 0.2297 - val_accuracy: 0.9125
# Epoch 48/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 0.9414 - val_loss: 0.2324 - val_accuracy: 0.9031
# Epoch 00048: early stopping

# %%
preds=model.predict_classes(scaledtest)
accuracy_score(y_true=ytest,y_pred=preds)
# Out:
# c:\users\pc\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 0.903125
